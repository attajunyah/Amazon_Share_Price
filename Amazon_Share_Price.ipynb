# %%
# %matplotlib inline
import pandas as pd 
import mplfinance as mpf

# %%
file = 'AMZN.csv'
data = pd.read_csv(file)

# %%
data
# Out:
#            Date         Open         High          Low        Close  \
# 0    2021-01-19  3107.000000  3145.000000  3096.000000  3120.760010
# 1    2021-01-20  3181.989990  3279.800049  3175.000000  3263.379883
# 2    2021-01-21  3293.000000  3348.550049  3289.570068  3306.989990
# 3    2021-01-22  3304.310059  3321.909912  3283.159912  3292.229980
# 4    2021-01-25  3328.500000  3363.889893  3243.149902  3294.000000
# ..          ...          ...          ...          ...          ...
# 247  2022-01-10  3211.709961  3233.229980  3126.090088  3229.719971
# 248  2022-01-11  3230.000000  3327.000000  3214.030029  3307.239990
# 249  2022-01-12  3331.500000  3337.560059  3288.340088  3304.139893
# 250  2022-01-13  3305.010010  3324.429932  3221.820068  3224.280029
# 251  2022-01-14  3203.000000  3245.000000  3196.010010  3242.760010
#
#        Adj Close   Volume
# 0    3120.760010  3305100
# 1    3263.379883  5309800
# 2    3306.989990  4936100
# 3    3292.229980  2821900
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       252 non-null    object
#  1   Open       252 non-null    float64
#  2   High       252 non-null    float64
#  3   Low        252 non-null    float64
#  4   Close      252 non-null    float64
#  5   Adj Close  252 non-null    float64
#  6   Volume     252 non-null    int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 13.9+ KB

# %%
data.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Adj Close', 'Volume'], dtype='object')

# %%
data.Date = pd.to_datetime(data.Date)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252 entries, 0 to 251
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       252 non-null    datetime64[ns]
#  1   Open       252 non-null    float64
#  2   High       252 non-null    float64
#  3   Low        252 non-null    float64
#  4   Close      252 non-null    float64
#  5   Adj Close  252 non-null    float64
#  6   Volume     252 non-null    int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 13.9 KB

# %%
data = data.set_index('Date')

# %%
data
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 2021-01-19  3107.000000  3145.000000  3096.000000  3120.760010  3120.760010
# 2021-01-20  3181.989990  3279.800049  3175.000000  3263.379883  3263.379883
# 2021-01-21  3293.000000  3348.550049  3289.570068  3306.989990  3306.989990
# 2021-01-22  3304.310059  3321.909912  3283.159912  3292.229980  3292.229980
# 2021-01-25  3328.500000  3363.889893  3243.149902  3294.000000  3294.000000
# ...                 ...          ...          ...          ...          ...
# 2022-01-10  3211.709961  3233.229980  3126.090088  3229.719971  3229.719971
# 2022-01-11  3230.000000  3327.000000  3214.030029  3307.239990  3307.239990
# 2022-01-12  3331.500000  3337.560059  3288.340088  3304.139893  3304.139893
# 2022-01-13  3305.010010  3324.429932  3221.820068  3224.280029  3224.280029
# 2022-01-14  3203.000000  3245.000000  3196.010010  3242.760010  3242.760010
#
#              Volume
# Date
# 2021-01-19  3305100
# ...

# %%
mpf.plot(data)

# %%
mpf.plot(data,type='line', volume=True)

# %%
#How do we plot a single month's data?
mpf.plot(data['2021-03'], volume=True)

# %%
mpf.plot(data['2021-03': '2021-07'], type='candle', mav=(20), volume=True, tight_layout=True)

# %%
mpf.plot(data['2021-03': '2021-07'], figratio=(20,12), 
         type='candle', 
         title = 'Amazon Price 2021/2022',
         mav=(20), volume=True, 
         tight_layout=True)

# %%
mpf.plot(data['2021-03': '2021-07'], figratio=(20,12), 
         type='candle', 
         title = 'Amazon Price 2021/2022',
         mav=(20), volume=True, 
         tight_layout=True, style='yahoo')
